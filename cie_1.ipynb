# %% [markdown]
# <a href="https://colab.research.google.com/github/Nohan28/iris/blob/main/cie_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Iris.csv')
plt.scatter(df['PetalLengthCm'], df['PetalWidthCm'])
plt.xlabel('Petal Length cm')
plt.ylabel('Petal Width cm')
plt.title('Petal Length vs Petal Width')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Iris.csv')
plt.bar(counts.index, counts.values)
plt.ylabel('speciess')
plt.xlabel('speciess')
plt.title(' flowers belong to each species')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Iris.csv')
df.boxplot(column='PetalLengthCm', by='Species',)
plt.title('Comparison of Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.grid(True)
plt.show()
